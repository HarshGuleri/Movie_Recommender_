# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head(6)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# 3               http://www.thedarkknightrises.com/   49026
# 4             http://movies.disney.com/john-carter   49529
# 5  http://www.sonypictures.com/movies/spider-man3/     559
#
#                                             keywords original_language  \
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head(4)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# budget
# homepage
# id
# original_language
# original_title
# popularity
# production_comapny
# production_countries
# release-date(not sure)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies = movies[['movie_id','title','overview','genres','keywords','budget','vote_average','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
import ast

# %%
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name']) 
    return L

# %%
movies.dropna(inplace=True)

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
keyword_counts = movies['keywords'].explode().value_counts()

# Select the top N keywords for visualization (e.g., top 10)
top_keywords = keyword_counts.head(10)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
top_keywords.plot(kind='bar', color='skyblue')
plt.xlabel('Keywords')
plt.ylabel('Frequency')
plt.title('Top 10 Movie Keywords')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout for better display
plt.show()

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
genre_counts = movies['genres'].value_counts()
genre_counts.plot(kind='pie')
plt.title('Genre Distribution')
plt.show()

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# CAST POPULARITY
cast_votes = movies['cast'].explode().value_counts()
cast_popularity = cast_votes.groupby(level=0).sum().reset_index(name='vote_count')
cast_popularity['popularity'] = cast_popularity['vote_count'] / cast_popularity['vote_count'].sum()
cast_popularity = cast_popularity.nlargest(10, 'popularity')
cast_popularity.plot(kind='bar', x='cast', y='popularity')
plt.title('Cast Popularity')
plt.show()

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
# movies['overview'] = movies['overview'].apply(lambda x:x.split())
movies.sample(5)
# Out:
#       movie_id                  title  \
# 3066       404     The Straight Story
# 296       9946            End of Days
# 3657     51384          Lovely, Still
# 4753    139998  Supporting Characters
# 1957     36696             Space Dogs
#
#                                                overview  \
# 3066  "The Straight Story" chronicles a trip made by...
# 296   On December 28th, 1999, the citizens of New Yo...
# 3657  A holiday fable that tells the story of an eld...
# 4753  Two New York film editors balance their person...
# 1957  Belka, the amazing flying dog is unexpectedly ...
#
#                                   genres  \
# 3066                             [Drama]
# 296   [Action, Fantasy, Horror, Mystery]
# 3657                    [Drama, Romance]
# 4753                     [Drama, Comedy]
# 1957                 [Family, Animation]
#
#                                                keywords     budget  \
# ...

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Flatten the 'crew' column which contains lists of directors
directors_list = [director for sublist in movies['crew'] for director in sublist]

# Count the occurrences of each director
director_counts = Counter(directors_list)

# Convert the Counter object to a dictionary for plotting
director_counts_dict = dict(director_counts)

# Sort the director counts dictionary by values in descending order
sorted_directors = dict(sorted(director_counts_dict.items(), key=lambda item: item[1], reverse=True))

# Extract top N directors for better visualization
top_directors = dict(list(sorted_directors.items())[:10])  # Adjust the number as needed

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.barh(list(top_directors.keys()), list(top_directors.values()), color='skyblue')
plt.xlabel('Number of Movies Directed')
plt.ylabel('Director')
plt.title('Top Directors by Number of Movies Directed')
plt.gca().invert_yaxis()  # Invert y-axis for better readability
plt.show()

# %%
#BUDGET

# %%
import matplotlib.pyplot as plt

# Assuming 'movies' is your DataFrame containing movie data
# Assuming you have numerical columns like 'budget' and 'vote_average'

# Extracting relevant columns for the scatter plot
scatter_data = movies[['budget', 'vote_average']]

# Removing rows with missing data (NaN values)
scatter_data = scatter_data.dropna()

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(scatter_data['budget'], scatter_data['vote_average'], alpha=0.5)
plt.xlabel('Budget')
plt.ylabel('Vote Average')
plt.title('Scatter Plot of Budget vs. Vote Average')
plt.grid(True)
plt.show()

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.sample(6)
# Out:
#       movie_id               title  \
# 540      11375  Hollywood Homicide
# 2236     10929             Willard
# 2000     10316   The Ides of March
# 119        272       Batman Begins
# 4401     29015        The Specials
# 2315    244339      Out of Inferno
#
#                                                overview  \
# 540   Joe Gavilan (Harrison Ford) and his new partne...
# 2236  Desperate for companionship, the repressed Wil...
# 2000  Dirty tricks stand to soil an ambitious young ...
# 119   Driven by tragedy, billionaire Bruce Wayne ded...
# 4401  America's 7th Best Superhero Team, the Special...
# 2315  On the hottest day in 50 years, a serious fire...
#
#                                      genres  \
# 540   [Action, Adventure, Comedy, Thriller]
# 2236                               [Horror]
# 2000                                [Drama]
# 119                  [Action, Crime, Drama]
# 4401                       [Action, Comedy]
# 2315                               [Action]
# ...

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title     budget  \
# 0     19995                                    Avatar  237000000
# 1       285  Pirates of the Caribbean: At World's End  300000000
# 2    206647                                   Spectre  245000000
# 3     49026                     The Dark Knight Rises  250000000
# 4     49529                               John Carter  260000000
#
#    vote_average                                               tags
# 0           7.2  In the 22nd century, a paraplegic Marine is di...
# 1           6.9  Captain Barbossa, long believed to be dead, ha...
# 2           6.3  A cryptic message from Bond’s past sends him o...
# 3           7.6  Following the death of District Attorney Harve...
# 4           6.1  John Carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer #count no. of time word appear
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
# genre_counts = movies['genres'].apply(lambda x: x[0]).value_counts()

# %%
similarity
# Out:
# array([[1.        , 0.08964215, 0.06071767, ..., 0.02519763, 0.0277885 ,
#         0.        ],
#        [0.08964215, 1.        , 0.06350006, ..., 0.02635231, 0.        ,
#         0.        ],
#        [0.06071767, 0.06350006, 1.        , ..., 0.02677398, 0.        ,
#         0.        ],
#        ...,
#        [0.02519763, 0.02635231, 0.02677398, ..., 1.        , 0.07352146,
#         0.04774099],
#        [0.0277885 , 0.        , 0.        , ..., 0.07352146, 1.        ,
#         0.05264981],
#        [0.        , 0.        , 0.        , ..., 0.04774099, 0.05264981,
#         1.        ]])

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# 744

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Gandhi')
# Out:
# Gandhi, My Father
# The Wind That Shakes the Barley
# A Passage to India
# Guiana 1838
# Ramanujan

# %%
recommend('Avatar')
# Out:
# Titan A.E.
# Small Soldiers
# Ender's Game
# Aliens vs Predator: Requiem
# Independence Day

# %%
recommend('The')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 recommend('The')
#
# Cell In[175], line 4, in recommend(movie)
#       3 def recommend(movie):
# ----> 4     index = new[new['title'] == movie].index[0]
#       5     distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
#       6     recommended_movies = [new.iloc[i[0]].title for i in distances[1:6]]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5175, in Index.__getitem__(self, key)
#    5172 if is_integer(key) or is_float(key):
#    5173     # GH#44051 exclude bool, which would return a 2d ndarray
#    5174     key = com.cast_scalar_indexer(key)
# -> 5175     return getitem(key)
#    5177 if isinstance(key, slice):
#    5178     # This case is separated from the conditional above to avoid
# ...

# %%
# import pickle

# %%
# pickle.dump(new,open('movie_list.pkl','wb'))
# pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
recommend('Hulk')
# Out:
# ['The Incredible Hulk',
#  'Shin Godzilla',
#  'The Island of Dr. Moreau',
#  'The Helix... Loaded',
#  'A Monster in Paris']

# %%
import matplotlib.pyplot as plt

# %%
movies.head(20)
# Out:
#     movie_id                                        title  \
# 0      19995                                       Avatar
# 1        285     Pirates of the Caribbean: At World's End
# 2     206647                                      Spectre
# 3      49026                        The Dark Knight Rises
# 4      49529                                  John Carter
# 5        559                                 Spider-Man 3
# 6      38757                                      Tangled
# 7      99861                      Avengers: Age of Ultron
# 8        767       Harry Potter and the Half-Blood Prince
# 9     209112           Batman v Superman: Dawn of Justice
# 10      1452                             Superman Returns
# 11     10764                            Quantum of Solace
# 12        58   Pirates of the Caribbean: Dead Man's Chest
# 13     57201                              The Lone Ranger
# 14     49521                                 Man of Steel
# ...

# %%
import matplotlib.pyplot as plt

def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_movies = [new.iloc[i[0]].title for i in distances[1:6]]
    return recommended_movies

# Example usage:
recommended_movies = recommend('The Lego Movie')

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.barh(recommended_movies, [5, 4, 3, 2, 1])  # You can adjust the scores as needed
plt.xlabel('Similarity Score')
plt.title('Top 5 Recommended Movies')
plt.gca().invert_yaxis()  # Invert y-axis for better visualization
plt.show()
